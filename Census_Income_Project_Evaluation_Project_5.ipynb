# %% [markdown]
# # Problem Statement:- In this dataset our target variable is "Income" (greater than or less than 50k) and we have many independent variable also.This is the problem of classification.

# %% [markdown]
# Importing important libraries of python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#lOADING THE DATASET.
df=pd.read_csv("censusincomep.csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#lets check the dimensions of the dataset
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# Our dataset has 32560 rows and 15 columns.

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# WOW!,Our dataset do not have any missing values.

# %% [raw]
# Lets do the "EXPLORATORY DATA ANALYSIS"

# %%
#Lets check the counts of different Workclass category in our dataset.
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Workclass", data=df)

# %% [markdown]
# We can see that most of the people in our dataset are "Privately Employed"

# %%
#Lets check the counts of different Education category in our dataset.
sns.set(rc={'figure.figsize':(7,7)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Education", data=df)

# %% [markdown]
# We can see that most of people in our dataset are "HS-grad" or  in "some-college".
#
# Very few people have done education less than 10th class.
#
# Very less people have the doctorate.

# %%
#Lets check the counts of different Marital_status category in our dataset.
sns.set(rc={'figure.figsize':(7,7)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Marital_status", data=df)

# %% [markdown]
# Most of the people are "Married" and few people  belong to "separated" and "widowed" category.

# %%
#Lets check the counts of different Occupation category in our dataset.
sns.set(rc={'figure.figsize':(7,7)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Occupation", data=df)

# %% [markdown]
# "Executives Managerial","Craft-repair","Professors" ---- These jobs categories are dominating.
# "Priv-house-serv","Armed-Forces"---These job categories are very less in our dataset.

# %%
#Lets check the counts of different Race category in our dataset.
sns.set(rc={'figure.figsize':(7,7)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Race", data=df)

# %% [markdown]
# Most people belongs to "White" category in our dataset
# Very less people are the "Amer-Indian-Eskimo","Asian-Pac-Islander" & "Black".

# %%
#Lets check the counts of different Native_country category in our dataset.
sns.set(rc={'figure.figsize':(12,12)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Native_country", data=df)

# %% [markdown]
# 1.We can see from above plot that most people are from "USA".
# 2.Very few people are from different native nations like ,"Mexico","India","Phillipines","Germany","Canada" etc.

# %%
#Lets check the counts of different Income category in our dataset.
sns.set(rc={'figure.figsize':(7,7)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(y="Income", data=df)

# %% [markdown]
# We can see that most people are having the salaries less than or equal to 50K
# Less people are having salaries greater than 50K

# %%
#Lets plot the Age distribution curve.  
sns.histplot(data=df, x="Age", kde=True)

# %% [markdown]
# We can see that distribution curve of the "Age" is skewed to the right.

# %%
#Lets plot the Hours_per_week distribution curve.  
sns.histplot(data=df, x="Hours_per_week", kde=True)

# %% [markdown]
# The distribution graph of the "Hoours_per_week" is approximately normally distributed.

# %%
#Lets plot the Capitai_gain distribution curve.  
sns.histplot(data=df, x="Capital_gain", kde=True)

# %%
#Lets plot the Capital_loss distribution curve.  
sns.histplot(data=df, x="Capital_loss", kde=True)

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df["Native_country"].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [markdown]
# From dataset we can see that the column "Education_num"  shows the number which represents the level of education.Greater the number means higher the education,so there is no need to keep extra 'Education' column.

# %%
#lets delete the education column.
df=df.drop(['Education'], axis = 1)

# %%
len(df["Education_num"].value_counts())
# Out:
# 16

# %%
df
# Out:
#        Age          Workclass  Fnlwgt  Education_num       Marital_status  \
# 0       50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 1       38            Private  215646              9             Divorced
# 2       53            Private  234721              7   Married-civ-spouse
# 3       28            Private  338409             13   Married-civ-spouse
# 4       37            Private  284582             14   Married-civ-spouse
# ...    ...                ...     ...            ...                  ...
# 32555   27            Private  257302             12   Married-civ-spouse
# 32556   40            Private  154374              9   Married-civ-spouse
# 32557   58            Private  151910              9              Widowed
# 32558   22            Private  201490              9        Never-married
# 32559   52       Self-emp-inc  287927              9   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Capital_gain  \
# ...

# %%
#count plot for the dependents and gender.
sns.set(rc={'figure.figsize':(12,12)})
ax = sns.countplot(y="Native_country", hue="Income", data=df)

# %%
#lets drop the Native_country since approximately same kind of income percent present for all countries
df=df.drop(['Native_country'], axis = 1)

# %%
df
# Out:
#        Age          Workclass  Fnlwgt  Education_num       Marital_status  \
# 0       50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 1       38            Private  215646              9             Divorced
# 2       53            Private  234721              7   Married-civ-spouse
# 3       28            Private  338409             13   Married-civ-spouse
# 4       37            Private  284582             14   Married-civ-spouse
# ...    ...                ...     ...            ...                  ...
# 32555   27            Private  257302             12   Married-civ-spouse
# 32556   40            Private  154374              9   Married-civ-spouse
# 32557   58            Private  151910              9              Widowed
# 32558   22            Private  201490              9        Never-married
# 32559   52       Self-emp-inc  287927              9   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Capital_gain  \
# ...

# %%
#Checking for the outliers.
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["Age"])

# %% [markdown]
# We can see that outliers are present in our age column.

# %%
#Checking for the outliers.
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["Hours_per_week"])

# %% [markdown]
# Hours_per_week column has many outliers.

# %%
#Checking for the outliers.
sns.set(rc={'figure.figsize':(5,5)})
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["Fnlwgt"])

# %% [markdown]
# Fnlwgt column also has many outliers present in it.

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["Capital_gain"])

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["Capital_loss"])

# %% [markdown]
# Both Capital_loss and Capital gain has many outliers.

# %%
#Lets do the outlier treatment.
#Defining a function which return the list of indices where outliers are present.
def outliers(dataframe,feature):
    Q1=dataframe[feature].quantile(0.25)
    Q3=dataframe[feature].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    ls=dataframe.index[(dataframe[feature]<lower_bound) | (dataframe[feature]>upper_bound)]
    return ls

# %%
#Create an empty list to store the output indices from the multiple columns.

index_list=[]
for feature in["Age"]:
    index_list.extend(outliers(df,feature))

# %%
len(index_list)
# Out:
# 143

# %% [markdown]
# We can see that in 143 rows of "Age we have outlier ,we will remove them.
# We are not considering columns like "Hours_per_week","Fnlwgt","Capital_gain","Capital_loss",for outlier removal since it has majority of outliers in them we cannot discard them if we discard the outliers from them we will loose great amount of the data.

# %%
#define  a function called remove  which returns a cleaned dataframe without outliers
def remove(dataframe,index_list):
    index_list=sorted(set(index_list))
    dataframe=dataframe.drop(index_list)
    return dataframe

# %%
df_cl=remove(df,index_list)

# %%
#This is our cleaned dataframe without outliers in "Age" column.
df_cl
# Out:
#        Age          Workclass  Fnlwgt  Education_num       Marital_status  \
# 0       50   Self-emp-not-inc   83311             13   Married-civ-spouse
# 1       38            Private  215646              9             Divorced
# 2       53            Private  234721              7   Married-civ-spouse
# 3       28            Private  338409             13   Married-civ-spouse
# 4       37            Private  284582             14   Married-civ-spouse
# ...    ...                ...     ...            ...                  ...
# 32555   27            Private  257302             12   Married-civ-spouse
# 32556   40            Private  154374              9   Married-civ-spouse
# 32557   58            Private  151910              9              Widowed
# 32558   22            Private  201490              9        Never-married
# 32559   52       Self-emp-inc  287927              9   Married-civ-spouse
#
#                Occupation    Relationship    Race      Sex  Capital_gain  \
# ...

# %%
#Checking the skewness in columns.
df_cl.skew()
# Out:
# Age                0.467740
# Fnlwgt             1.447235
# Education_num     -0.309683
# Capital_gain      11.950909
# Capital_loss       4.568042
# Hours_per_week     0.240598
# dtype: float64

# %%
#Lets remove the skewness.
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
pt.fit(df_cl.iloc[:,9:12])
df_cl.iloc[:,9:12]=pt.transform(df_cl.iloc[:,9:12])

# %%
fnl_array=df_cl["Fnlwgt"].to_numpy()
fnl_array=fnl_array.reshape(-1,1)

pt = PowerTransformer()
pt.fit(fnl_array)
df_cl["Fnlwgt"]=pt.transform(fnl_array)

# %%
df_cl
# Out:
#        Age          Workclass    Fnlwgt  Education_num       Marital_status  \
# 0       50   Self-emp-not-inc -1.090907             13   Married-civ-spouse
# 1       38            Private  0.397350              9             Divorced
# 2       53            Private  0.561143              7   Married-civ-spouse
# 3       28            Private  1.339059             13   Married-civ-spouse
# 4       37            Private  0.955798             14   Married-civ-spouse
# ...    ...                ...       ...            ...                  ...
# 32555   27            Private  0.745354             12   Married-civ-spouse
# 32556   40            Private -0.194617              9   Married-civ-spouse
# 32557   58            Private -0.221068              9              Widowed
# 32558   22            Private  0.270284              9        Never-married
# 32559   52       Self-emp-inc  0.980783              9   Married-civ-spouse
#
# ...

# %%
#Creating dummy columns for the nominal categorical variables and dropping one column from each to counter multicollinearity.
categorical_cols = ["Workclass","Marital_status","Occupation","Relationship","Race","Sex","Income"] 
df2 = pd.get_dummies(df_cl, columns = categorical_cols,drop_first=True)

# %%
df2
# Out:
#        Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# 0       50 -1.090907             13     -0.300877     -0.221188
# 1       38  0.397350              9     -0.300877     -0.221188
# 2       53  0.561143              7     -0.300877     -0.221188
# 3       28  1.339059             13     -0.300877     -0.221188
# 4       37  0.955798             14     -0.300877     -0.221188
# ...    ...       ...            ...           ...           ...
# 32555   27  0.745354             12     -0.300877     -0.221188
# 32556   40 -0.194617              9     -0.300877     -0.221188
# 32557   58 -0.221068              9     -0.300877     -0.221188
# 32558   22  0.270284              9     -0.300877     -0.221188
# 32559   52  0.980783              9      3.323671     -0.221188
#
#        Hours_per_week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# 0           -2.238778                       0                     0
# ...

# %%
df2.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32417.000000  3.241700e+04   32417.000000  3.241700e+04  3.241700e+04
# mean      38.381590 -1.985743e-16      10.083074  4.351710e-16  1.413313e-15
# std       13.330086  1.000015e+00       2.567856  1.000015e+00  1.000015e+00
# min       17.000000 -2.765129e+00       1.000000 -3.008767e-01 -2.211880e-01
# 25%       28.000000 -6.154843e-01       9.000000 -3.008767e-01 -2.211880e-01
# 50%       37.000000  5.253737e-02      10.000000 -3.008767e-01 -2.211880e-01
# 75%       47.000000  5.828292e-01      12.000000 -3.008767e-01 -2.211880e-01
# max       78.000000  6.041458e+00      16.000000  3.323677e+00  4.521041e+00
#
#        Hours_per_week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# count    3.241700e+04            32417.000000          32417.000000
# mean     4.400650e-16                0.029552              0.064287
# std      1.000015e+00                0.169352              0.245268
# ...

# %%
#lets plot the heatmap to check the correlation between dependent and independent  variables.
corr_mat=df2.corr()
plt.figure(figsize=[21,16])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
#Bifurcating the dataset into independent and dependent variables.
y=df2.iloc[:,-1]
x=df2.iloc[:,0:44]

# %%
x
# Out:
#        Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# 0       50 -1.090907             13     -0.300877     -0.221188
# 1       38  0.397350              9     -0.300877     -0.221188
# 2       53  0.561143              7     -0.300877     -0.221188
# 3       28  1.339059             13     -0.300877     -0.221188
# 4       37  0.955798             14     -0.300877     -0.221188
# ...    ...       ...            ...           ...           ...
# 32555   27  0.745354             12     -0.300877     -0.221188
# 32556   40 -0.194617              9     -0.300877     -0.221188
# 32557   58 -0.221068              9     -0.300877     -0.221188
# 32558   22  0.270284              9     -0.300877     -0.221188
# 32559   52  0.980783              9      3.323671     -0.221188
#
#        Hours_per_week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# 0           -2.238778                       0                     0
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income_ >50K, Length: 32417, dtype: uint8

# %% [markdown]
# Splitting the dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()
y_train=y_train.reshape(-1,1)
y_test=y_test.reshape(-1,1)

# %% [markdown]
# Standard scaling the dataset

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train.iloc[:,0:6]=sc.fit_transform(x_train.iloc[:,0:6])
x_test.iloc[:,0:6]=sc.transform(x_test.iloc[:,0:6])

# %% [markdown]
# Training the logistics regression model on training set

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(random_state=4)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
#importing important metrics
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[4585  376]
#  [ 614  909]]
# 0.8473164713140037

# %% [markdown]
# Training our model on KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
kn.fit(x_train,y_train)
y_pred=kn.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[4454  507]
#  [ 602  921]]
# 0.8289636027143739

# %% [markdown]
# Training our model on SVM linear kernel

# %%
from sklearn.svm import SVC
svml =SVC(kernel="linear",random_state=0)
svml.fit(x_train,y_train)
y_pred=svml.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[4581  380]
#  [ 626  897]]
# 0.8448488587291795

# %% [markdown]
# Training our model on SVM rbf kernel

# %%
from sklearn.svm import SVC
svmr =SVC(kernel="rbf",random_state=0)
svmr.fit(x_train,y_train)
y_pred=svmr.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[4628  333]
#  [ 636  887]]
# 0.8505552128315854

# %% [markdown]
# Training our dataset on Naive Bayes model

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
y_pred=gnb.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[2422 2539]
#  [  84 1439]]
# 0.5954657618753856

# %% [markdown]
# Training our model on Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion="entropy",random_state=0)
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[4336  625]
#  [ 568  955]]
# 0.8160086366440469

# %% [markdown]
# Training our model on Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10,criterion="entropy",random_state=1)
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[4610  351]
#  [ 640  883]]
# 0.8471622455274522

# %%
#Lets do the cross validation to check the overfitting of the models.
from sklearn.model_selection import cross_val_score

scr=cross_val_score(lr,x,y,cv=5)
print("Cross validation score of LogisticRegression model :",scr.mean())

scr=cross_val_score(kn,x,y,cv=5)
print("Cross validation score of KNN Classifier model :",scr.mean())

#scr=cross_val_score(svml,x,y,cv=5)
#print("Cross validation score of Support vector linear classifier model :",scr.mean())

#scr=cross_val_score(svmr,x,y,cv=5)
#print("Cross validation score of Support vector rbf classifier model :",scr.mean())

scr=cross_val_score(gnb,x,y,cv=5)
print("Cross validation score of Naive Bayes classifier model :",scr.mean())

scr=cross_val_score(dtc,x,y,cv=5)
print("Cross validation score of Decision Tree Classifier  model :",scr.mean())

scr=cross_val_score(rfc,x,y,cv=5)
print("Cross validation score of Randomforest Classifier  model :",scr.mean())
# Out:
# Cross validation score of LogisticRegression model : 0.8413796182927247
# Cross validation score of KNN Classifier model : 0.8203722010862557
# Cross validation score of Naive Bayes classifier model : 0.6337717075827702
# Cross validation score of Decision Tree Classifier  model : 0.8105625894059945
# Cross validation score of Randomforest Classifier  model : 0.8445570073032084

# %% [markdown]
# OUR BEST PERFORMING MODEL IS RANDOM FOREST CLASSIFIER,SINCE THE DIFFERENCE BETWEEN THE accuracy_score & cross_val_score IS LEAST FOR THE RANDOM FOREST CLASSIFIER.

# %%
Lets do the HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={"criterion":('gini', 'entropy'),"max_features":('auto', 'sqrt', 'log2'),"class_weight":('balanced', 'balanced_subsample')}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ('balanced', 'balanced_subsample'),
#                          'criterion': ('gini', 'entropy'),
#                          'max_features': ('auto', 'sqrt', 'log2')})

# %%
GCV.best_params_
# Out:
# {'class_weight': 'balanced_subsample',
#  'criterion': 'gini',
#  'max_features': 'sqrt'}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.8551819864281308

# %%
#Dumping our model
import joblib   
joblib.dump(GCV.best_estimator_,"Census_Income_rfc.pkl")
# Out:
# ['Census_Income_rfc.pkl']
